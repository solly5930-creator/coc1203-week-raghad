# %%
# ==============================
# Example 1: Password Check
# ==============================

password = input("Enter the password: ")

if password == "admin123":
    print("Access Granted")
else:
    print("Access Denied")


# ==============================
# Example 2: Age Category
# ==============================

age = int(input("Enter your age: "))

if age < 13:
    print("Child")
elif 13 <= age <= 19:
    print("Teen")
elif 20 <= age <= 59:
    print("Adult")
else:
    print("Senior")


# ==============================
# Example 3: Number Check
# ==============================

num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
else:
    print("Not Positive")

if 10 <= num <= 50:
    print("The number is between 10 and 50")
else:
    print("The number is NOT between 10 and 50")


# ==============================
# Example 4: Traffic Light (match)
# ==============================

color = input("Enter a color (red, yellow, green): ")

if color != "":
    match color.lower():
        case "red":
            print("Stop")
        case "yellow":
            print("Get Ready")
        case "green":
            print("Go")
        case _:
            print("Invalid color")
else:
    print("Input cannot be empty")


# ==============================
# Example 5: Calculator Menu
# ==============================

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = input("Choose an option (1-4): ")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

match choice:
    case "1":
        print("Result:", num1 + num2)
    case "2":
        print("Result:", num1 - num2)
    case "3":
        print("Result:", num1 * num2)
    case "4":
        if num2 != 0:
            print("Result:", num1 / num2)
        else:
            print("Cannot divide by zero")
    case _:
        print("Invalid choice")


# ==============================
# Example 6: Student Grade
# ==============================

score = int(input("Enter student score: "))

if score >= 50:
    print("Passed")
else:
    print("Failed")

if score >= 90:
    grade = "A"
elif score >= 80:
    grade = "B"
elif score >= 70:
    grade = "C"
elif score >= 50:
    grade = "D"
else:
    grade = "F"

match grade:
    case "A":
        print("Excellent")
    case "B":
        print("Very Good")
    case "C":
        print("Good")
    case "D":
        print("Pass")
    case "F":
        print("Fail")

# %%
num = int(input("Enter a number: "))

for i in range(1, 13):

    product = num * i

    if product > 50:
        break

    if product % 3 == 0:
        continue

    print(num, "x", i, "=", product)

# %%
# 3) Guessing game

import random

secret = random.randint(1, 20)
attempts = 0

while True:
    guess = int(input("Guess the number (1-20): "))

    if guess < 1 or guess > 20:
        continue

    attempts += 1   # augmented assignment

    if guess == secret:
        print("Correct! Attempts =", attempts)
        break

# %%
# 4) Count numbers divisible by 4

n = int(input("Enter a number: "))
count = 0

for i in range(1, n + 1):

    if i > 50:
        break

    if i % 8 == 0:
        continue

    if i % 4 == 0:
        count += 1

print("Count =", count)

# %%
# 5) Triangle pattern

for i in range(1, 6):

    for j in range(1, i + 1):

        if j == 3:
            continue

        if i * j > 6:
            break

        print(j, end=" ")

    print()
